# %% [markdown]
# # learn how to do image augmentation

# %%
import imgaug as ia
import numpy as np
import os
from keras.preprocessing import image
from imgaug import augmenters as iaa
from scipy.misc import imsave
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %%
data_dir = '/Users/xuan/work/dataset/cat-no-cat/img'
cat1 = imread(data_dir + "/cat/test.jpg")
plt.figure(0)
plt.imshow(cat1)
plt.title("Original Image with imread")
# Out:
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# Text(0.5,1,u'Original Image with imread')

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
data_generator = datagen.flow_from_directory( data_dir, target_size=(224, 224), batch_size=1, class_mode='binary')
def next_one():
    imgs = data_generator.next()[0]
    return imgs[0].astype(np.uint8)

plt.figure(figsize=(16,16))
SZ = 8
for i in range(SZ):
    plt.subplot(1,SZ,i+1)
    img = next_one()
    plt.imshow(img)
    imsave(data_dir + "/" + str(i) + ".png", img)
plt.draw()
# Out:
# Found 1 images belonging to 1 classes.
# /Library/Python/2.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
